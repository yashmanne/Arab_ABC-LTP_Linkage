# %%
import os

# %%
path = os.path.join('C:\\Users\\ysman\\OneDrive\\Desktop\\project_directory\\data\\BIOGRID-ORGANISM-Arabidopsis_thaliana_Columbia-3.5.181.tab2.txt')

# %%
bioGRID_file = open(path, "r")

# %%
testFile = open(os.path.join('C:\\Users\\ysman\\OneDrive\\Desktop\\project_directory\\data\\test.txt'), 'r')

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
pd.read_csv(bioGRID_file)

# %%
pd.read_csv(bioGRID_file, sep = '\t')
# Out:
#        #BioGRID Interaction ID  Entrez Gene Interactor A  \
# 0                       251838                    828230
# 1                       251839                    828230
# 2                       265014                    836259
# 3                       265015                    836259
# 4                       265016                    836259
# 5                       265017                    836259
# 6                       265018                    819292
# 7                       265019                    819292
# 8                       265021                    834224
# 9                       265022                    817111
# 10                      265023                    838604
# 11                      265024                    825172
# 12                      265025                    829569
# 13                      265026                    814846
# 14                      265027                    819203
# ...

# %%
#../ takes you one level up ../../

# %%
df = pd.read_csv("../data/BIOGRID-ORGANISM-Arabidopsis_thaliana_Columbia-3.5.181.tab2.txt", sep = '\t')
df
# Out:
#        #BioGRID Interaction ID  Entrez Gene Interactor A  \
# 0                       251838                    828230
# 1                       251839                    828230
# 2                       265014                    836259
# 3                       265015                    836259
# 4                       265016                    836259
# 5                       265017                    836259
# 6                       265018                    819292
# 7                       265019                    819292
# 8                       265021                    834224
# 9                       265022                    817111
# 10                      265023                    838604
# 11                      265024                    825172
# 12                      265025                    829569
# 13                      265026                    814846
# 14                      265027                    819203
# ...
